# %% [markdown]
# #Course : CS 513 - Knowledge discovery and Data mining
# #Course Instructor:- Khashayar Dehnad
# #First Name: Keval
# #Last Name: Sompura
# #Id: 20033127
# #Description: Exploratry Data Analysis of given dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
folder='C:/Users/Asus/OneDrive/Stevens/Sem-2/KDDM/HW2/'
file='breast-cancer-wisconsin.csv'
data = pd.read_csv(folder+file)
data.head()
# Out:
#     Sample  F1  F2   F3   F4  F5  F6   F7   F8  F9  Class
# 0  1000025   5   1  1.0  1.0   2   1  3.0  1.0   1      2
# 1  1002945   5   4  4.0  5.0   7  10  3.0  2.0   1      2
# 2  1015425   3   1  1.0  1.0   2   2  3.0  1.0   1      2
# 3  1016277   6   8  8.0  1.0   3   4  3.0  7.0   1      2
# 4  1017023   4   1  1.0  3.0   2   1  3.0  1.0   1      2

# %%
summary = data.describe().loc[["min", "max", "mean"]]
print(summary)
# Out:
#             Sample        F1         F2         F3         F4         F5  \
# min   6.163400e+04   1.00000   1.000000   1.000000   1.000000   1.000000
# max   1.345435e+07  10.00000  10.000000  10.000000  10.000000  10.000000
# mean  1.071704e+06   4.41774   3.134478   3.204871   2.803725   3.216023
#
#              F7         F8         F9     Class
# min    1.000000   1.000000   1.000000  2.000000
# max   10.000000  10.000000  10.000000  4.000000
# mean   3.432665   2.868195   1.589413  2.689557

# %%
missing_values = data.isnull().sum()
print(missing_values)
# Out:
# Sample    0
# F1        0
# F2        0
# F3        1
# F4        1
# F5        0
# F6        0
# F7        1
# F8        1
# F9        0
# Class     0
# dtype: int64

# %%
# Convert non-numeric values to NaN
data = data.apply(pd.to_numeric, errors='coerce')

# Fill NaN values with the mean of the column
data.fillna(data.mean(), inplace=True)
print(data.isnull().sum())
# Out:
# Sample    0
# F1        0
# F2        0
# F3        0
# F4        0
# F5        0
# F6        0
# F7        0
# F8        0
# F9        0
# Class     0
# dtype: int64

# %%
freq_table = pd.crosstab(data['Class'], data['F6'])
print(freq_table)
# Out:
# F6     1.000000   2.000000   3.000000   3.544656   4.000000   5.000000   \
# Class
# 2            387         21         14         14          6         10
# 4             15          9         14          2         13         20
#
# F6     6.000000   7.000000   8.000000   9.000000   10.000000
# Class
# 2              0          1          2          0          3
# 4              4          7         19          9        129

# %%
# %matplotlib inline

# %%
pd.plotting.scatter_matrix(data[['F1', 'F2', 'F3', 'F4', 'F5', 'F6']], figsize=(12, 12))
plt.show()

# %%
data[['F7', 'F8', 'F9']].boxplot()
plt.show()

# %%
# %reset -f

import pandas as pd
folder = 'C:/Users/Asus/OneDrive/Stevens/Sem-2/KDDM/HW2/'
file = 'breast-cancer-wisconsin.csv'
data = pd.read_csv(folder + file)

data.dropna(inplace=True)
data
# Out:
#       Sample  F1  F2    F3   F4  F5  F6    F7    F8  F9  Class
# 0    1000025   5   1   1.0  1.0   2   1   3.0   1.0   1      2
# 1    1002945   5   4   4.0  5.0   7  10   3.0   2.0   1      2
# 2    1015425   3   1   1.0  1.0   2   2   3.0   1.0   1      2
# 3    1016277   6   8   8.0  1.0   3   4   3.0   7.0   1      2
# 4    1017023   4   1   1.0  3.0   2   1   3.0   1.0   1      2
# ..       ...  ..  ..   ...  ...  ..  ..   ...   ...  ..    ...
# 694   776715   3   1   1.0  1.0   3   2   1.0   1.0   1      2
# 695   841769   2   1   1.0  1.0   2   1   1.0   1.0   1      2
# 696   888820   5  10  10.0  3.0   7   3   8.0  10.0   2      4
# 697   897471   4   8   6.0  4.0   3   4  10.0   6.0   1      4
# 698   897471   4   8   8.0  5.0   4   5  10.0   4.0   1      4
#
# [696 rows x 11 columns]
